# %%
# %run main.py -h
# Out:
# usage: main.py [-h] [--path PATH] [--voxels-frequency VOXELS_FREQUENCY]
#                [--num-layers NUM_LAYERS] [--hidden-size HIDDEN_SIZE]
#                [--num-samples NUM_SAMPLES] [--lr LR]
#                [--percentage-test PERCENTAGE_TEST]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --path PATH           path to the project's main folder
#   --voxels-frequency VOXELS_FREQUENCY
#                         frequency of voxels to send to the network
#   --num-layers NUM_LAYERS
#                         number of layers in the LSTM network
#   --hidden-size HIDDEN_SIZE
#                         size of the hidden layer(s) in the network
#   --num-samples NUM_SAMPLES
#                         number of data (chosen randomly) to send to the
#                         network
#   --lr LR               learning rate of the algorithm
#   --percentage-test PERCENTAGE_TEST
#                         percentage of data to use as testing

# %% [markdown]
# ## Previous

# %%
# %run main.py --path ../
# Out:
# start: 17:38:00.653996
# 1/4: 17:55:13.615692
# 1/4: 18:13:02.256959
# 1/4: 18:31:02.638251
# Random: 1.466992665036675 %
# Good predict: 96.14427860696517 %
# Saving network...

# %% [markdown]
# # Actual

# %%
# %run main_NN.py --path ../ --num-samples 200000 --percentage-test 20 --lr 5e-5 #1 fc layer
# Out:
# start: 14:56:29.291416
# 1/4: 15:22:23.411292
# 1/4: 15:49:41.230792
# 1/4: 16:17:42.976023
# Random: 0.8588957055214724 %
# Good predict: 67.72151898734177 %

# %%
# %run main_NN.py --path ../ --num-samples 40000 --percentage-test 20 --bidirectional True
# Out:
# start: 17:40:45.923746
# 1/4: 17:55:25.588902
# 1/4: 18:09:51.263602
# 1/4: 18:24:24.730773
# Random: 1.1002444987775062 %
# Good predict: 73.65591397849462 %

# %%
# %run main_NN.py --path ../ --num-samples 40000 --percentage-test 20 --lr 5e-5 --bidirectional True
# Out:
# start: 13:52:48.053789
# 1/4: 14:06:51.234121
# 2/4: 14:20:58.511532
# 3/4: 14:35:12.056747
# 4/4: 14:49:10.737215
# Random: 2.078239608801956 %
# Good predict: 67.05202312138728 %

# %% [markdown]
# # 2 layers

# %%
# %run main_NN.py --path ../ --num-samples 40000 --percentage-test 20 --lr 5e-5 --bidirectional True
# Out:
# start: 14:52:32.217358
# 1/4: 15:06:49.404698
# 2/4: 15:21:12.417124
# 3/4: 15:35:18.705560
# 4/4: 15:49:29.620042
# Random: 1.8450184501845017 %
# Good predict: 71.15384615384616 %

# %% [markdown]
# # Better datatest

# %%
# %run main_NN.py --path ../ --percentage-test 20 --lr 5e-5 --bidirectional True --dropout 0.1 --num-samples 40000
# Out:
# 175
# [[696], [696], [696], [794], [696], [823], [546], [546], [68], [68], [68], [68], [68], [693], [693], [693], [597], [46], [266], [46], [681], [353], [353], [1022], [1022], [1022], [120], [635], [3], [3], [741], [741], [741], [882], [882], [271], [977], [271], [39], [39], [607], [39], [607], [802], [182], [182], [537], [182], [182], [182], [182], [898]]
# start: 11:42:23.961472
# 38 159
# 64 159
# 74 159
# 85 159
# 85 159
# 89 159
# 92 159
# 1/4: 11:57:52.350892
# 93 159
# 90 159
# 99 159
# 97 159
# 96 159
# 100 159
# 100 159
# 98 159
# 2/4: 12:13:09.782496
# 99 159
# 104 159
# 106 159
# 102 159
# 105 159
# 108 159
# 106 159
# 3/4: 12:28:10.359085
# 110 159
# 108 159
# 105 159
# 108 159
# 114 159
# 107 159
# 108 159
# 109 159
# 4/4: 12:43:37.988896
# 593 659
# Good train predict: 89.98482549317147 %
# 114 159
# Good test predict: 71.69811320754717 %
# Saving network...

# %% [markdown]
# # Batch

# %%
# %run main_NN.py --path ../ --num-samples 5500 --percentage-test 20 --num-layers 1 --hidden-size 128
# Out:
# 159
# start: 16:02:16.506897
# 1/4: 16:03:30.044889
# 2/4: 16:04:43.566987
# 3/4: 16:05:56.631449
# 4/4: 16:07:13.083598
# Good train predict: 94.08194233687405 %
# Good test predict: 74.21383647798741 %
# Saving network...

# %%
# %run main_NN.py --path ../ --num-samples 5500 --percentage-test 20 --num-layers 1 --hidden-size 128
# Out:
# 159
# start: 10:37:08.818586
# 1/4: 10:38:15.465675
# 2/4: 10:39:25.001604
# 3/4: 10:40:34.081141
# 4/4: 10:41:43.010154
# Good train predict: 94.99241274658573 %
# Good test predict: 64.15094339622641 %
# Saving network...
