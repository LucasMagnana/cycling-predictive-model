# %%
# %run main.py -h
# Out:
# usage: main.py [-h] [--path PATH] [--voxels-frequency VOXELS_FREQUENCY]
#                [--num-layers NUM_LAYERS] [--hidden-size HIDDEN_SIZE]
#                [--num-samples NUM_SAMPLES] [--lr LR]
#                [--percentage-test PERCENTAGE_TEST]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --path PATH           path to the project's main folder
#   --voxels-frequency VOXELS_FREQUENCY
#                         frequency of voxels to send to the network
#   --num-layers NUM_LAYERS
#                         number of layers in the LSTM network
#   --hidden-size HIDDEN_SIZE
#                         size of the hidden layer(s) in the network
#   --num-samples NUM_SAMPLES
#                         number of data (chosen randomly) to send to the
#                         network
#   --lr LR               learning rate of the algorithm
#   --percentage-test PERCENTAGE_TEST
#                         percentage of data to use as testing

# %%
# %run main.py --path ../ --num-samples 90000
# Out:
# start: 18:59:58.622669
# 1/4: 19:14:24.856547
# 1/4: 19:29:35.194467
# 1/4: 19:45:01.552693
# Random: 1.5892420537897312 %
# Good predict: 95.59902200488997 %
# Saving network...

# %% [markdown]
# # Bikepath fusion v2

# %%
# %run main.py --path ../ --num-samples 115000
# Out:
# start: 16:24:31.066343
# 1/4: 16:42:52.253121
# 1/4: 17:01:46.726720
# 1/4: 17:20:22.213212
# Random: 1.466992665036675 %
# Good predict: 96.08801955990221 %
# Saving network...

# %%
# %run main.py --path ../ --num-samples 115000
# Out:
# start: 00:14:29.759864
# 1/4: 00:14:32.377013
# 1/4: 00:14:34.331037
# 1/4: 00:14:36.453065
# 1/4: 00:14:38.589858
# Random: 0.7334963325183375 %
# Good predict: 19.682151589242054 %

# %% [markdown]
# ## OSMNX

# %%
# %run main.py --path ../
# Out:
# start: 17:38:00.653996
# 1/4: 17:55:13.615692
# 1/4: 18:13:02.256959
# 1/4: 18:31:02.638251
# Random: 1.466992665036675 %
# Good predict: 96.14427860696517 %
# Saving network...

# %%
# %run main.py --path ../
# Out:
# start: 15:12:25.475721
# 1/4: 15:24:15.884058
# 1/4: 15:36:22.679096
# 1/4: 15:48:54.501347
# Random: 0.9779951100244498 %
# Good predict: 96.14427860696517 %
# Saving network...

# %%
# %run main.py --path ../ --num-samples 100 --hidden-size 128 --percentage-test 20
# Out:
# start: 11:16:42.462992
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/FAC/Stage M2/bikesharing/python/main.py in <module>
#     159     parse.add_argument('--percentage-test', type=int, default=0, help='percentage of data to use as testing')
#     160
# --> 161     main(parse.parse_args())
#
# ~/FAC/Stage M2/bikesharing/python/main.py in main(args)
#     100     loss = nn.NLLLoss()
#     101
# --> 102     tab_loss, tab_predict = learning.train(df_train, tab_clusters, loss, optimizer, network, size_data, cuda, args.num_samples, df_test)
#     103
#     104     g_predict = learning.test(df_test, None, tab_clusters, size_data, cuda)
#
# ~/FAC/Stage M2/bikesharing/python/learning.py in train(df, tab_clusters, loss, optimizer, network, size_data, cuda, nb_step, df_test)
#     153 def train(df, tab_clusters, loss, optimizer, network, size_data, cuda, nb_step, df_test=None):
# ...
