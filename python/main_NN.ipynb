# %%
# %run main.py -h
# Out:
# usage: main.py [-h] [--path PATH] [--voxels-frequency VOXELS_FREQUENCY]
#                [--num-layers NUM_LAYERS] [--hidden-size HIDDEN_SIZE]
#                [--num-samples NUM_SAMPLES] [--lr LR]
#                [--percentage-test PERCENTAGE_TEST]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --path PATH           path to the project's main folder
#   --voxels-frequency VOXELS_FREQUENCY
#                         frequency of voxels to send to the network
#   --num-layers NUM_LAYERS
#                         number of layers in the LSTM network
#   --hidden-size HIDDEN_SIZE
#                         size of the hidden layer(s) in the network
#   --num-samples NUM_SAMPLES
#                         number of data (chosen randomly) to send to the
#                         network
#   --lr LR               learning rate of the algorithm
#   --percentage-test PERCENTAGE_TEST
#                         percentage of data to use as testing

# %%
# %run main_NN.py --path ../ --num-samples 8000 --percentage-test 20 --project-folder "veleval_walk"
# Out:
# test: 384 noise: 383 train: 1535
# start: 18:47:31.286413
# 1/4: 18:52:21.674853
# 2/4: 18:57:16.506174
# 3/4: 19:01:57.644066
# 4/4: 19:06:48.361383
# Good train predict: 97.45928338762215 %
# Good test predict: 68.48958333333334 %
# Saving network...

# %%
# %run main_NN.py --path ../ --num-samples 7500 --percentage-test 20
# Out:
# 583 471 2265
# start: 16:33:49.502071
# 1/4: 16:41:32.413846
# 2/4: 16:49:35.347221
# 3/4: 16:57:35.956419
# 4/4: 17:04:31.755846
# Good train predict: 97.52759381898454 %
# Good test predict: 85.07718696397941 %
# Saving network...
# ...

# %%
# %run main_NN.py --path ../ --num-samples 7500 --percentage-test 20 --project-folder "monresovelo"
# Out:
# 591 1530 2201
# start: 14:54:51.072097
# 1/4: 15:02:35.128898
# 2/4: 15:09:31.083054
# 3/4: 15:16:44.991052
# 4/4: 15:23:45.401463
# Good train predict: 95.82008178100864 %
# Good test predict: 54.82233502538071 %
# Saving network...

# %%
# %run main_NN.py --path ../ --num-samples 7500 --percentage-test 20
# Out:
# 583 471 2265
# start: 16:01:28.542822
# 1/4: 16:06:15.665987
# 2/4: 16:10:59.109626
# 3/4: 16:15:58.839066
# 4/4: 16:21:16.211022
# Good train predict: 97.35099337748345 %
# Good test predict: 77.18696397941682 %
# Saving network...
