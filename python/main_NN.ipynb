# %%
# %run main.py -h
# Out:
# usage: main.py [-h] [--path PATH] [--voxels-frequency VOXELS_FREQUENCY]
#                [--num-layers NUM_LAYERS] [--hidden-size HIDDEN_SIZE]
#                [--num-samples NUM_SAMPLES] [--lr LR]
#                [--percentage-test PERCENTAGE_TEST]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --path PATH           path to the project's main folder
#   --voxels-frequency VOXELS_FREQUENCY
#                         frequency of voxels to send to the network
#   --num-layers NUM_LAYERS
#                         number of layers in the LSTM network
#   --hidden-size HIDDEN_SIZE
#                         size of the hidden layer(s) in the network
#   --num-samples NUM_SAMPLES
#                         number of data (chosen randomly) to send to the
#                         network
#   --lr LR               learning rate of the algorithm
#   --percentage-test PERCENTAGE_TEST
#                         percentage of data to use as testing

# %% [markdown]
# ## Previous

# %%
# %run main.py --path ../
# Out:
# start: 17:38:00.653996
# 1/4: 17:55:13.615692
# 1/4: 18:13:02.256959
# 1/4: 18:31:02.638251
# Random: 1.466992665036675 %
# Good predict: 96.14427860696517 %
# Saving network...

# %% [markdown]
# # Actual

# %%
# %run main_NN.py --path ../ --num-samples 5500 --percentage-test 20 --num-layers 1 --hidden-size 128
# Out:
# 159
# start: 12:59:33.555040
# 1/4: 13:00:47.964158
# 2/4: 13:02:13.506531
# 3/4: 13:03:32.370493
# 4/4: 13:04:49.046434
# Good train predict: 89.68133535660091 %
# Good test predict: 73.58490566037736 %
# Saving network...
# ...

# %%
# %run main_NN.py --path ../ --num-samples 10000 --percentage-test 20 --project-folder "veleval_walk"
# Out:
# 573 552 2224
# start: 15:28:16.717722
# /home/lmagnana/.local/lib/python3.8/site-packages/torch/autograd/__init__.py:130: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   Variable._execution_engine.run_backward(
# 1/4: 15:35:52.971962
# 2/4: 15:43:43.017913
# 3/4: 15:50:55.630707
# 4/4: 15:58:18.750748
# Good train predict: 96.80755395683454 %
# Good test predict: 84.81675392670157 %
# Saving network...

# %%
# %run main_NN.py --path ../ --num-samples 10000 --percentage-test 20
# Out:
# 566 547 2206
# start: 14:55:59.325523
# /home/lmagnana/.local/lib/python3.8/site-packages/torch/autograd/__init__.py:130: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   Variable._execution_engine.run_backward(
# 1/4: 15:03:35.463745
# 2/4: 15:11:50.731094
# 3/4: 15:20:09.278503
# 4/4: 15:27:45.471552
# Good train predict: 96.78150498640072 %
# Good test predict: 84.62897526501767 %
# Saving network...
# ...
