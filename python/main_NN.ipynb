# %%
# %run main.py -h
# Out:
# usage: main.py [-h] [--path PATH] [--voxels-frequency VOXELS_FREQUENCY]
#                [--num-layers NUM_LAYERS] [--hidden-size HIDDEN_SIZE]
#                [--num-samples NUM_SAMPLES] [--lr LR]
#                [--percentage-test PERCENTAGE_TEST]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --path PATH           path to the project's main folder
#   --voxels-frequency VOXELS_FREQUENCY
#                         frequency of voxels to send to the network
#   --num-layers NUM_LAYERS
#                         number of layers in the LSTM network
#   --hidden-size HIDDEN_SIZE
#                         size of the hidden layer(s) in the network
#   --num-samples NUM_SAMPLES
#                         number of data (chosen randomly) to send to the
#                         network
#   --lr LR               learning rate of the algorithm
#   --percentage-test PERCENTAGE_TEST
#                         percentage of data to use as testing

# %% [markdown]
# ## Previous

# %%
# %run main.py --path ../
# Out:
# start: 17:38:00.653996
# 1/4: 17:55:13.615692
# 1/4: 18:13:02.256959
# 1/4: 18:31:02.638251
# Random: 1.466992665036675 %
# Good predict: 96.14427860696517 %
# Saving network...

# %% [markdown]
# # Actual

# %%
# %run main_NN.py --path ../ --num-samples 5500 --percentage-test 20 --num-layers 1 --hidden-size 128
# Out:
# 159
# start: 12:59:33.555040
# 1/4: 13:00:47.964158
# 2/4: 13:02:13.506531
# 3/4: 13:03:32.370493
# 4/4: 13:04:49.046434
# Good train predict: 89.68133535660091 %
# Good test predict: 73.58490566037736 %
# Saving network...
# ...

# %%
# %run main_NN.py --path ../ --num-samples 10000 --percentage-test 20 --project-folder "veleval_full"
# Out:
# 596
# start: 12:48:19.545925
# 1/4: 12:55:40.959845
# 2/4: 13:01:43.993560
# 3/4: 13:07:43.229907
# 4/4: 13:13:53.824850
# Good train predict: 96.7609676096761 %
# Good test predict: 83.05369127516778 %
# Saving network...

# %%
# %run main_NN.py --path ../ --num-layers 2 --num-samples 7500 --percentage-test 20 --project-folder "veleval_full"
# Out:
# 596 284 2439
# start: 15:51:51.771839
# 1/4: 15:56:27.692675
# 2/4: 16:01:02.666953
# 3/4: 16:05:56.080505
# 4/4: 16:10:41.174303
# Good train predict: 96.4739647396474 %
# Good test predict: 81.3758389261745 %
# Saving network...
